# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
# i want to modify this part

# %%
data = pd.read_csv('./Data/Africa_Vectors_database_1898-2016.csv', sep = ',', encoding = "ISO-8859-1")

# %%
data
# Out:
#         Country         GAUL_Admin1    GAUL_Admin2  \
# 0        Angola               Bengo          Dande
# 1        Angola               Bengo          Dande
# 2        Angola               Bengo          Dande
# 3        Angola               Bengo          Dande
# 4        Angola               Bengo         Dembos
# 5        Angola               Bengo  Icolo E Bengo
# 6        Angola               Bengo  Icolo E Bengo
# 7        Angola               Bengo  Icolo E Bengo
# 8        Angola               Bengo  Icolo E Bengo
# 9        Angola               Bengo  Icolo E Bengo
# 10       Angola               Bengo       Quissama
# 11       Angola               Bengo       Quissama
# 12       Angola               Bengo       Quissama
# 13       Angola            Benguela     Baia Farta
# 14       Angola            Benguela        Balombo
# 15       Angola            Benguela        Balombo
# 16       Angola            Benguela        Balombo
# ...

# %%
columns = np.array(data.columns)

# %%
for i in range (len(columns)):
    print(columns[i])
# Out:
# Country
# GAUL_Admin1
# GAUL_Admin2
# Full_Name
# Lat
# Long
# LatLong_Source
# YeStart
# YeEnd
# An gambiae_complex
# An gambiae ss
# SS M Form (An colluzzi or Mopti forms)
# SS S Form (savanah or Bamako forms)
# An arabiensis
# An. melas
# An. merus
# An bwambae
# An funestus  s.l
# An funestus s.s. (specified)
# An rivulorum
# An leesoni
# An parensis
# An vaneedeni
# An nili s.l
# An moucheti s.l
# An pharoensis
# An hancocki
# An mascarensis
# An marshalli
# An squamous
# An wellcomei
# An rufipes
# An coustani s.l
# An ziemanni
# An paludis
# Adults/Larvae
# Sampling_Methods
# Species_Identification
# Other sib species names
# Other Anopheline species
# Source_Title

# %%
idx = np.array(data.index)

# %%
len(idx)
# Out:
# 13464

# %%
data.iloc[:10,:10]
# Out:
#   Country GAUL_Admin1    GAUL_Admin2       Full_Name     Lat     Long  \
# 0  Angola       Bengo          Dande  Barra do Dande -8.4730  13.3620
# 1  Angola       Bengo          Dande       Boa Vista -8.5990  13.5660
# 2  Angola       Bengo          Dande         Cabungo -8.5667  13.5000
# 3  Angola       Bengo          Dande          Lifune -8.4000  13.4490
# 4  Angola       Bengo         Dembos          Dembos -8.5156  14.5189
# 5  Angola       Bengo  Icolo E Bengo       Bom Jesus -9.1660  13.5660
# 6  Angola       Bengo  Icolo E Bengo   Icolo e Bengo -9.2500  13.7333
# 7  Angola       Bengo  Icolo E Bengo         Kilunda -8.9268  13.5878
# 8  Angola       Bengo  Icolo E Bengo     Lagoa Banda -8.8503  13.5842
# 9  Angola       Bengo  Icolo E Bengo          Mazozo -9.1020  13.6220
#
#   LatLong_Source  YeStart  YeEnd An gambiae_complex
# 0        Encarta     1967   1967                  Y
# 1        Encarta     1987   1987                  Y
# ...

# %%
data.iloc[:10,10:20]
# Out:
#   An gambiae ss SS M Form (An colluzzi or Mopti forms)  \
# 0           NaN                                    NaN
# 1           NaN                                    NaN
# 2             Y                                    NaN
# 3           NaN                                    NaN
# 4           NaN                                    NaN
# 5           NaN                                    NaN
# 6           NaN                                    NaN
# 7           NaN                                    NaN
# 8           NaN                                    NaN
# 9           NaN                                    NaN
#
#   SS S Form (savanah or Bamako forms) An arabiensis An. melas An. merus  \
# 0                                 NaN           NaN       NaN       NaN
# 1                                 NaN           NaN       NaN       NaN
# 2                                   Y           NaN       NaN       NaN
# ...

# %%
data.iloc[:10,20:30]
# Out:
#   An leesoni An parensis An vaneedeni An nili s.l An moucheti s.l  \
# 0        NaN         NaN          NaN         NaN             NaN
# 1        NaN         NaN          NaN         NaN             NaN
# 2        NaN         NaN          NaN         NaN             NaN
# 3        NaN         NaN          NaN         NaN             NaN
# 4        NaN         NaN          NaN         NaN             NaN
# 5        NaN         NaN          NaN         NaN             NaN
# 6        NaN         NaN          NaN         NaN             NaN
# 7        NaN         NaN          NaN         NaN             NaN
# 8        NaN         NaN          NaN         NaN             NaN
# 9        NaN         NaN          NaN         NaN             NaN
#
#   An pharoensis An hancocki An mascarensis An marshalli An squamous
# 0           NaN         NaN            NaN          NaN         NaN
# 1           NaN         NaN            NaN          NaN         NaN
# ...

# %%
data.iloc[:10,30:]
# Out:
#   An wellcomei An rufipes An coustani s.l An ziemanni  An paludis   \
# 0          NaN        NaN             NaN          NaN         NaN
# 1          NaN        NaN             NaN          NaN         NaN
# 2          NaN        NaN             NaN          NaN         NaN
# 3          NaN        NaN               Y            Y         NaN
# 4          NaN        NaN             NaN          NaN         NaN
# 5          NaN        NaN               Y            Y         NaN
# 6          NaN        NaN             NaN          NaN         NaN
# 7          NaN        NaN             NaN          NaN         NaN
# 8          NaN        NaN               Y            Y         NaN
# 9          NaN        NaN             NaN          NaN         NaN
#
#     Adults/Larvae   Sampling_Methods Species_Identification  \
# 0  Adults, Larvae       HLC, HBC, LC                      M
# 1  Adults, Larvae            PSC, LC                      M
# ...

# %%
plt.plot(data.Lat, data.Long, marker = '.')
